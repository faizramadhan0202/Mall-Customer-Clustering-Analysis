# %% [markdown]
# <center><bold><h2>Mall Customer Clustering Analysis
# <h2/><bold/><center/>

# %% [markdown]
# <strong>Introduction<strong/>

# %% [markdown]
# Mall Customer Clustering Analysis is a shopping center that sells various kinds of goods. Customer analysis will be carried out using Python. Analysis is carried out with the aim of finding new information and answering questions such as customer gender, customer age and customer income and expenses and many more.

# %% [markdown]
# <strong>Table Of Contents<strong/>

# %% [markdown]
# 1. <a style="text-decoration:none" href="#Importinng Libraries">Importinng Libraries<a/><br>
# 2. <a style="text-decoration:none" href="#Data Cleaning">Data Cleaning<a/><br>
# 3. <a style="text-decoration:none" href="#Exploratory Data Analysis">Exploratory Data Analysis<a/><br>
#     a. <a style="text-decoration:none" href="#Pairplot"> Pairplot<a/><br>
#     b. <a style="text-decoration:none" href="#HeatMap"> HeatMap<a/><br>
#     c. <a style="text-decoration:none" href="#dabl Spending Score"> dabl Spending Score<a/><br>
#     d. <a style="text-decoration:none" href="#dabl Annual Income"> dabl Annual Income<a/><br>
#     e. <a style="text-decoration:none" href="#Descriptive Stantistic"> Descriptive Stantistic<a/><br>
# 4. <a style="text-decoration:none" href="#Data vizualization"> Data vizualization<a/><br>
#     a. <a style="text-decoration:none" href="#Subplot"> Subplot<a/><br>
#     b. <a style="text-decoration:none" href="#Pie chart"> Pie chart<a/><br>
#     c. <a style="text-decoration:none" href="#Countplot"> Countplot<a/><br>
#     d. <a style="text-decoration:none" href="#Histplot"> Histplot<a/><br>
#     e. <a style="text-decoration:none" href="#boxenplot"> Boxenplot<a/><br>
#     f. <a style="text-decoration:none" href="#Violinplot"> Violinplot<a/><br>
#     g. <a style="text-decoration:none" href="#Boxplot"> Boxplot<a/><br>
# 5. <a style="text-decoration:none" href="#Clustering Analysis">Clustering Analysis<a/><br>
# 6. <a style="text-decoration:none" href="#KMeans Algorithm"> KMeans Algorithm<a/><br>
#     a. <a style="text-decoration:none" href="#Visualization The Clusters"> Visualization The Clusters<a/><br>
#     b. <a style="text-decoration:none" href="#Clustering between Age and Spending Score"> Clustering between Age and Spending Score<a/><br>
#     c. <a style="text-decoration:none" href="#Cluster of Ages"> Cluster of Ages<a/><br>

# %% [markdown]
# <strong id="Importinng Libraries">Importinng Libraries<strong/>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use('fivethirtyeight')
import dabl

# %%
from google.colab import files

files_uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c6272a8-7573-483a-b36d-3598921a388c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c6272a8-7573-483a-b36d-3598921a388c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %% [markdown]
# <strong id="Data Cleaning">Data Cleaning<strong/>

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# <strong id="Exploratory Data Analysis">Exploratory Data Analysis<strong>

# %% [markdown]
# <small id="Pairplot">Pairplot<small/>

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# <small id="HeatMap">HeatMap<small/>

# %%
sns.heatmap(df.corr(), annot=True, cmap='copper')
plt.title('Correlation HeatMap Of The Data', fontsize=15)
plt.show()
# Out:
# <ipython-input-38-b282280243a9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='copper')

# %% [markdown]
# <small id="dabl Spending Score">dabl Spending Score<small/>

# %%
dabl.plot(df, target_col = 'Spending Score (1-100)')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='Spending Score (1...', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=-3.45E-01'}, xlabel='Age', ylabel='Spending Score (1...'>,
#          <Axes: title={'center': 'F=7.84E-03'}, xlabel='Annual Income (k$)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=4.84E-02'}, xlabel='Spending Score (1-100)', ylabel='Gender'>]],
#        dtype=object)]

# %% [markdown]
# <small id="dabl Annual Income">dabl Annual Income <small/>

# %%
dabl.plot(df, target_col = 'Annual Income (k$)')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='Annual Income (k$)', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=1.98E-02'}, xlabel='Age', ylabel='Annual Income (k$)'>,
#          <Axes: title={'center': 'F=7.84E-03'}, xlabel='Spending Score (1-100)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=7.27E-03'}, xlabel='Annual Income (k$)', ylabel='Gender'>]],
#        dtype=object)]

# %% [markdown]
# <small id="Descriptive Stantistic">Descriptive Stantistic <small/>

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.describe(include = 'object')
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112

# %% [markdown]
# <strong id="Data vizualization"> Data vizualization <strong/>

# %% [markdown]
# <small id="Subplot"> Subplot <small/>

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (18,8)

plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(df['Annual Income (k$)'])
plt.title('Distribution Annual Income (k$)', fontsize=20)
plt.xlabel('Range Annual Income')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.set(style = 'whitegrid')
sns.distplot(df['Age'], color='red')
plt.title('Distribution of Age', fontsize=20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <small id="Pie chart"> Pie chart <small/>

# %%
labels = ['Female', 'Male']
size = df['Gender'].value_counts()
colors = ['lightgreen', 'orange']
explode = [0, 0.001]

plt.rcParams['figure.figsize'] = (18,8)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, startangle = 90, autopct = '%.2f%%')
plt.title('Gender Gap', size = 10)
plt.axis = 'off'
plt.legend()
plt.show()

# %% [markdown]
# <small id="Countplot"> Countplot <small/>

# %%
plt.figure(figsize = (13, 15))
plt.style.use('fivethirtyeight')

ax = sns.countplot(y = 'Age', data = df, palette = 'hsv', hue="Age")
ax.set_xlabel(xlabel = 'Distribution of Age', fontsize = 15)
ax.set_ylabel(ylabel = 'Count')
ax.set_title(label = 'Distribution of Age', fontsize= 20)
plt.show()

# %% [markdown]
# <small id="Histplot"> Histplot <small/>

# %%
plt.rcParams['figure.figsize'] = (20,8)
sns.histplot(df['Annual Income (k$)'])
plt.title('Distribution Annual Income (k$)', fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,8)
sns.histplot(df['Spending Score (1-100)'], color = 'black')
plt.title('Distribution of Spending Score', fontsize=20)
plt.show()

# %% [markdown]
# <small id="boxenplot"> boxenplot <small/>

# %%
plt.rcParams['figure.figsize'] = (18,7)
sns.boxenplot(x=df['Gender'], y=df['Spending Score (1-100)'], palette = 'Blues', hue=df['Gender'])
plt.title('Gender vs Spending Score')
plt.show()

# %% [markdown]
# <small id="Violinplot"> Violinplot <small/>

# %%
plt.rcParams['figure.figsize'] = (18,7)
sns.violinplot(x=df['Gender'], y=df['Annual Income (k$)'], palette = 'rainbow', hue=df['Gender'])
plt.title('Gender vs Annual Income')
plt.show()

# %% [markdown]
# <small id="Boxplot"> Boxplot <small/>

# %%
plt.rcParams['figure.figsize'] = (18,7)
sns.boxplot(x=df['Gender'], y=df['Age'], palette = 'Purples', hue=df['Gender'])
plt.title('Gender vs Annual Income')
plt.show()

# %% [markdown]
# <strong id="Clustering Analysis"> Clustering Analysis<strong/>

# %%
import warnings
warnings.filterwarnings('ignore')

x = df.loc[:, ['Spending Score (1-100)','Annual Income (k$)']].values

print(x.shape)
# Out:
# (200, 2)

# %%
#lets also check the data, which we are going to use for the clustering analysis
x_data = pd.DataFrame(x)
x_data.head()
#where 0 -> spending Score and 1 Annual Income
# Out:
#     0   1
# 0  39  15
# 1  81  15
# 2   6  16
# 3  77  16
# 4  40  17

# %% [markdown]
# <strong id="KMeans Algorithm"> KMeans Algorithm <strong/>

# %%
#The Elbow Method to find the No.of Optional Clusters
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
  km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0 )
  km.fit(x)
  wcss.append(km.inertia_)

plt.plot(range(1,11), wcss)
plt.title('The Elbow Method', fontsize = 15)
plt.xlabel('No. of Cluster')
plt.ylabel('No wcss')
plt.show()

# %% [markdown]
# <small id="Visualization The Clusters"> Visualization The Clusters <small/>

# %%
plt.style.use('fivethirtyeight')

km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'pink', label = 'miser')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'yellow', label = 'general')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 100, c = 'cyan', label = 'target')
plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 100, c = 'magenta', label = 'spendthrift')
plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 100, c = 'orange', label = 'careful')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

plt.style.use('fivethirtyeight')
plt.title('K Means Clustering between Annual Income and Spending Score', fontsize = 20)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <small id="Clustering between Age and Spending Score">Clustering between Age and Spending Score<small/>

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
  km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0 )
  km.fit(x)
  wcss.append(km.inertia_)

plt.rcParams['figure.figsize'] = (15, 8)
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method', fontsize = 15)
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid()
plt.show()

# %% [markdown]
# <small id="Cluster of Ages"> Cluster of Ages <small/>

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
ymeans = kmeans.fit_predict(x)

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Cluster of Ages', fontsize = 30)

plt.scatter(x[ymeans == 0, 0], x[ymeans == 0, 1], s = 100, c = 'pink', label = 'Usual Customers' )
plt.scatter(x[ymeans == 1, 0], x[ymeans == 1, 1], s = 100, c = 'orange', label = 'Priority Customers')
plt.scatter(x[ymeans == 2, 0], x[ymeans == 2, 1], s = 100, c = 'lightgreen', label = 'Target Customers(Young)')
plt.scatter(x[ymeans == 3, 0], x[ymeans == 3, 1], s = 100, c = 'red', label = 'Target Customers(Old)')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 50, c = 'black')

plt.style.use('fivethirtyeight')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.grid()
plt.show()
